# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavi-sreeji/DeepLearning/blob/main/handwritten_digits_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np

              # loading the data set

(x_train,y_train),(x_test,y_test)=keras.datasets.mnist.load_data()

#print(x_train.shape)#(60000, 28, 28)
#print(x_test.shape)#(10000, 28, 28)
#print(x_train[0])# 2 dimensional matrix
#plt.matshow(x_train[0]) #to display the imge in 0 index
#print(y_train[0]) # here it displays the label

x_train=x_train/255.0
x_test=x_test/255.0

#print(x_train[0])# 2 dimensional matrix

x_train_flattened = x_train.reshape(len(x_train),28*28) #to become 1 dimensional
x_test_flattened=x_test.reshape(len(x_test),28*28)
#print(x_train_flattened[0])

                       #for just input and output layer

"""model=keras.Sequential([keras.layers.Dense(10,input_shape=(784,),activation='sigmoid')])
model.compile(optimizer='adam',loss="sparse_categorical_crossentropy",metrics="accuracy")
model.fit(x_train_flattened,y_train,epochs=5)

model.evaluate(x_test_flattened,y_test)


plt.matshow(x_test[0])
#model.predict(x_test_flattened)

y_predicted=model.predict(x_test_flattened)
#print(y_predicted[0])


#print(np.argmax(y_predicted[0]))

y_predicted_labels=[np.argmax(i) for i in y_predicted]

 # to get confusion matrix

cm=tf.math.confusion_matrix(labels=y_test,predictions=y_predicted_labels)
#print(cm)

import seaborn as sn
plt.figure(figsize=(10,7))
sn.heatmap(cm,annot=True,fmt="d")
plt.xlabel("predicted")
plt.ylabel('Truth')"""

           #here added 1 hidden layer also

model=keras.Sequential([
     keras.layers.Dense(100,input_shape=(784,),activation='relu'),
     keras.layers.Dense(10,input_shape=(784,),activation='sigmoid')])
model.compile(optimizer='adam',loss="sparse_categorical_crossentropy",metrics="accuracy")
model.fit(x_train_flattened,y_train,epochs=5)

#model.save("model1.h5")
#model=tf.keras.models.load_model("model1.h5")

model.evaluate(x_test_flattened,y_test)


plt.matshow(x_test[0])
#model.predict(x_test_flattened)

y_predicted=model.predict(x_test_flattened)
#print(y_predicted[0])


#print(np.argmax(y_predicted[0]))

y_predicted_labels=[np.argmax(i) for i in y_predicted]

 # to get confusion matrix

cm=tf.math.confusion_matrix(labels=y_test,predictions=y_predicted_labels)
#print(cm)

import seaborn as sn
plt.figure(figsize=(10,7))
sn.heatmap(cm,annot=True,fmt="d")
plt.xlabel("predicted")
plt.ylabel('Truth')
# Out:
# ...
# 11490434/11490434 [==============================] - 1s 0us/step
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2727 - accuracy: 0.9229
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1221 - accuracy: 0.9636
# Epoch 3/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0852 - accuracy: 0.9748
# Epoch 4/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0654 - accuracy: 0.9801
# Epoch 5/5
# ...
# 313/313 [==============================] - 1s 1ms/step
# Text(95.72222222222221, 0.5, 'Truth')
